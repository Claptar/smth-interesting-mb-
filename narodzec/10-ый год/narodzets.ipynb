# %%
import os
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from laba import*

# %%
file1 = 'Elections.xlsx'
data = pd.read_excel(file1, sheet_name=0)
file2 = 'Elections.xlsx'
data2 = pd.read_excel(file2, sheet_name=1)
data['Процент за Лукашенко'] = data2['Лукашенко А.Г.'][1::2].values
data['Кол-во голосов за Лукашенко'] = data2['Лукашенко А.Г.'][0::2].values
data['вид территориальной единицы'] = data['Наименование административно- территориальной единицы'].str.contains('г. ')
data['вид территориальной единицы'].replace(True, 'город', inplace=True)
data['вид территориальной единицы'].replace(False, 'район', inplace=True)
data
# Out:
#     Наименование административно- территориальной единицы  \
# 0                                  Барановичский район
# 1                                    Берёзовский район
# 2                                      Брестский район
# 3                                   Ганцевичский район
# 4                                   Дрогичинский район
# ..                                                 ...
# 143                        Партизанский район г. Минск
# 144                        Первомайский район г. Минск
# 145                           Советский район г. Минск
# 146                         Фрунзенский район г. Минск
# 147                         Центральный район г. Минск
#
#      Общее число избирателей  \
# 0                      31407
# 1                      49030
# 2                      27542
# 3                      22205
# 4                      30895
# ..                       ...
# 143                    73358
# 144                   158358
# ...
